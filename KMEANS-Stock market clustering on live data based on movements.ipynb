# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.simplefilter("ignore")

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\aksha\anaconda3\lib\site-packages (0.9.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: lxml in c:\users\aksha\anaconda3\lib\site-packages (from pandas_datareader) (4.5.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aksha\anaconda3\lib\site-packages (from pandas_datareader) (2.24.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\aksha\anaconda3\lib\site-packages (from pandas_datareader) (1.0.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aksha\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aksha\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\aksha\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aksha\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\aksha\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\aksha\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\aksha\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.15.0)

# %%
from pandas_datareader import data #https://bit.ly/2SEL507

# %%
companies_dict={
    'Amazon':'AMZN',
    'Apple':'AAPL',
    'Walgreen':'WBA',
    'Northrop Grumman Corporation':'NOC',
    'Boeing':'BA',
    'Lockheed Martin':'LMT',
    'McDonalds':'MCd',
    'Intel':'INTC',
    'Navister':'NAV',
    'IBM':'IBM',
    'Texas Instruments':'TXN',
    'mastercard':'MA',
    'Microsoft':'MSFT',
    'General Electrics':'GE',
    'American Express':'AXP',
    'Pepsi':'PEP',
    'Coca cola':'KO',
    'Jhonson & Jhonson':'JNJ',
    'Toyota':'TM',
    'Honda':'HMc',
    'Mitsubishi Corporation':'8058.T',
    'Sony Group Corporation':'SONY',
    'Exxon':'XOM',
    'Chevron':'CVX',
    'Valero Energy Corporation':'VLO',
    'Ford':'F',
    'Bank of America Corporation':'BAC'}

# %%
data_source='yahoo'
start_date='2015-04-25'
end_date='2020-04-25'
df=data.DataReader(list(companies_dict.values()),data_source,start_date,end_date)

# %%
df.head()
# Out:
# Attributes   Adj Close                                                \
# Symbols           AMZN       AAPL        WBA         NOC          BA
# Date
# 2015-04-24  445.100006  29.742304  73.431702  146.707657  130.596771
# 2015-04-27  438.559998  30.283358  73.551285  145.211411  130.068787
# 2015-04-28  429.309998  29.806231  73.517113  145.555969  129.813538
# 2015-04-29  429.369995  29.367901  72.227478  144.313583  128.616730
# 2015-04-30  421.779999  28.571152  70.826820  139.688736  126.143806
#
# Attributes                                                           ...  \
# Symbols            LMT        MCd       INTC        NAV         IBM  ...
# Date                                                                 ...
# 2015-04-24  166.500504  84.084412  27.255543  30.160000  131.424652  ...
# 2015-04-27  165.196625  82.125793  27.612375  29.940001  132.159988  ...
# 2015-04-28  165.350037  82.457924  28.054171  29.900000  134.629410  ...
# 2015-04-29  163.023483  82.619690  27.943726  30.150000  135.000916  ...
# 2015-04-30  159.026489  82.219467  27.654858  29.959999  132.593491  ...
#
# Attributes      Volume                                                         \
# Symbols            JNJ        TM        HMc     8058.T       SONY         XOM
# Date
# 2015-04-24   6566900.0  277500.0   824800.0        NaN  3291100.0   8405700.0
# 2015-04-27   9113900.0  273000.0   557200.0  4079100.0  1472600.0  10534600.0
# 2015-04-28   7484600.0  421900.0  2455300.0  6382600.0   957100.0   9633800.0
# 2015-04-29   8926200.0  282900.0  1481400.0        NaN  1089200.0  12534100.0
# 2015-04-30  10170600.0  246800.0   750000.0  7040100.0  1271100.0  13947700.0
#
# Attributes
# Symbols           CVX        VLO           F          BAC
# Date
# 2015-04-24  4995000.0  5277700.0  20293300.0   40766100.0
# 2015-04-27  4858700.0  8056400.0  34824900.0   73523400.0
# 2015-04-28  5321600.0  7905400.0  56634200.0   58080100.0
# 2015-04-29  5665800.0  6002600.0  35126900.0  134499400.0
# 2015-04-30  6666800.0  8067500.0  30269300.0   78313900.0
#
# [5 rows x 162 columns]

# %%
df.isna().sum()
# Out:
# Attributes  Symbols
# Adj Close   AMZN       42
#             AAPL       42
#             WBA        42
#             NOC        42
#             BA         42
#                        ..
# Volume      XOM        42
#             CVX        42
#             VLO        42
#             F          42
#             BAC        42
# Length: 162, dtype: int64

# %%
df.describe()
# Out:
# Attributes    Adj Close                                                      \
# Symbols            AMZN         AAPL          WBA          NOC           BA
# count       1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean        1216.227929    39.716459    65.088212   253.262964   235.501009
# std          535.809753    13.966320     9.632395    64.126292   101.889736
# min          419.100006    21.134403    38.584244   138.999573    95.010002
# 25%          742.567505    27.242883    58.090172   200.404888   128.415546
# 50%         1033.824951    38.038097    68.473427   254.732346   227.869774
# 75%         1760.752441    47.787975    72.546480   305.130753   337.740982
# max         2410.219971    81.170799    82.894539   376.678833   430.299988
#
# Attributes                                                                   \
# Symbols             LMT          MCd         INTC          NAV          IBM
# count       1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean         268.360389   141.246405    39.146619    27.628452   125.313610
# std           65.019398    37.706112    10.253321    10.186118    10.625938
# min          159.026489    78.347046    22.322298     6.230000    89.788025
# 25%          212.799660   107.194338    30.646500    19.295000   120.615118
# 50%          275.468292   145.961639    37.258320    29.190001   126.476822
# 75%          310.423042   171.664600    47.235264    34.745001   131.386360
# max          425.574005   212.002670    66.405708    47.450001   151.120636
#
# Attributes  ...        Volume                                            \
# Symbols     ...           JNJ            TM           HMc        8058.T
# count       ...  1.260000e+03  1.260000e+03  1.260000e+03  1.242000e+03
# mean        ...  7.393197e+06  2.461264e+05  6.836130e+05  5.132084e+06
# std         ...  3.462506e+06  1.680426e+05  3.754513e+05  2.356226e+06
# min         ...  2.353800e+06  4.840000e+04  1.047000e+05  0.000000e+00
# 25%         ...  5.447700e+06  1.385000e+05  4.249750e+05  3.631375e+06
# 50%         ...  6.609750e+06  1.961000e+05  5.720500e+05  4.695650e+06
# 75%         ...  8.358525e+06  3.022000e+05  8.293250e+05  6.063475e+06
# max         ...  5.814020e+07  2.073300e+06  2.736400e+06  1.951060e+07
#
# Attributes                                                          \
# Symbols             SONY           XOM           CVX           VLO
# count       1.260000e+03  1.260000e+03  1.260000e+03  1.260000e+03
# mean        1.187470e+06  1.375182e+07  7.498412e+06  4.590480e+06
# std         7.760476e+05  8.303944e+06  3.969848e+06  2.062394e+06
# min         1.882000e+05  3.851300e+06  1.640100e+06  5.598000e+05
# 25%         7.145500e+05  9.385425e+06  5.065850e+06  3.083525e+06
# 50%         9.871500e+05  1.148710e+07  6.345300e+06  4.116600e+06
# 75%         1.399975e+06  1.491728e+07  8.346050e+06  5.658375e+06
# max         8.331100e+06  7.989150e+07  4.269370e+07  1.464570e+07
#
# Attributes
# Symbols                F           BAC
# count       1.260000e+03  1.260000e+03
# mean        4.034802e+07  7.802267e+07
# std         2.190955e+07  3.842499e+07
# min         7.760600e+06  1.380540e+07
# 25%         2.717878e+07  5.301502e+07
# 50%         3.498480e+07  6.834645e+07
# 75%         4.581335e+07  9.230488e+07
# max         2.318008e+08  3.750887e+08
#
# [8 rows x 162 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1302 entries, 2015-04-24 to 2020-04-24
# Columns: 162 entries, ('Adj Close', 'AMZN') to ('Volume', 'BAC')
# dtypes: float64(162)
# memory usage: 1.6 MB

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Attributes  Symbols
# Adj Close   AMZN       0
#             AAPL       0
#             WBA        0
#             NOC        0
#             BA         0
#                       ..
# Volume      XOM        0
#             CVX        0
#             VLO        0
#             F          0
#             BAC        0
# Length: 162, dtype: int64

# %%
stock_open=np.array(df['Open']).T #stock open is numpy array of transpose of df[open]
stock_close=np.array(df['Close']).T #stock open is numpy array of transpose of df[open]

# %%
movements=stock_close-stock_open#Difference of opening and closing prices
movements
# Out:
# array([[ 6.1000061 , -5.29998779, -9.20001221, ..., -5.51000977,
#         -0.5300293 , -6.7800293 ],
#        [-0.05250168,  0.08499908, -0.97500229, ...,  0.62250519,
#         -0.20999908,  1.44249725],
#        [-1.18000031, -0.56999969,  0.24000549, ...,  0.40999985,
#          0.36999893,  0.05000305],
#        ...,
#        [ 0.64999771, -0.90999985, -1.11999893, ..., -1.40000153,
#          0.04999924, -0.29999924],
#        [ 0.04000092,  0.07999992,  0.12999916, ..., -0.0999999 ,
#          0.08999968, -0.05999994],
#        [-0.06999969, -0.06999969,  0.06999969, ..., -0.36000061,
#         -0.08999825,  0.06999969]])

# %%
sum_of_movement=np.sum(movements,1)  #Sum of difference of closing and opening prices of all days

# %%
for i in range(len(companies_dict)):
    print('company:{},change{}'.format(df['High'].columns[i],sum_of_movement[i]))
# Out:
# company:AMZN,change-165.81925354003943
# company:AAPL,change47.50489088694269
# company:WBA,change-38.73965657552134
# company:NOC,change81.1371485392242
# company:BA,change-76.75647176106787
# company:LMT,change47.21331787109466
# company:MCd,change52.56578776041721
# company:INTC,change43.56533514658595
# company:NAV,change-40.093304459253886
# company:IBM,change-12.141445922851062
# company:TXN,change48.401254653930465
# company:MA,change71.74442825317396
# company:MSFT,change33.24223289489771
# company:GE,change-7.650626850128191
# company:AXP,change-8.338826243082707
# company:PEP,change54.74612960815435
# company:KO,change13.98096326192207
# company:JNJ,change48.6491854349772
# company:TM,change-53.74369252522749
# company:HMc,change-22.1443375905355
# company:8058.T,change98.01690821258126
# company:SONY,change-19.88140010833736
# company:XOM,change-24.53142178853335
# company:CVX,change-22.18562850952179
# company:VLO,change-31.134251658121826
# company:F,change-15.448345454533872
# company:BAC,change2.4386406898497555

# %%
plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
plt.title('company:Amazon',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Opening_price',fontsize=15)
plt.plot(df['Open']['AMZN'])

plt.subplot(1,2,2)
plt.title('company:Apple',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Opening_price',fontsize=15)
plt.plot(df['Open']['AAPL'])

# %%
plt.figure(figsize=(20,10))
plt.title('company:Apple',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.plot(df.iloc[0:100]["Open"]["AAPL"],label='Open') #Opening price of 30 days plotted against Dates
plt.plot(df.iloc[0:100]["Close"]["AAPL"],label='Close') #Closing price of 30 days plotted against Dates
plt.legend(loc='upper left',frameon=False,framealpha=1,prop={'size':22}) #Properties of legend box

# %%
plt.figure(figsize=(20,10))
plt.title('company:Amazon',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Day',fontsize=15)
plt.ylabel('movements',fontsize=15)
plt.plot(movements[1][0:200])

# %%
#Volume of stock traded
plt.figure(figsize=(20,10))
plt.title('company:Amazon',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Day',fontsize=15)
plt.ylabel('Volume',fontsize=15)
plt.plot(df['Volume']['AMZN'],label='Open')

# %%
plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
plt.title('company:Amazon',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Movement',fontsize=15)
plt.plot(movements[1])

plt.subplot(1,2,2)
plt.title('company:Apple',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Movement',fontsize=15)
plt.plot(movements[0])

# %%
from sklearn.preprocessing import Normalizer
normalizer=Normalizer()
norm_movements=normalizer.fit_transform(movements)

# %%
print(norm_movements.min())
print(norm_movements.max())
print(norm_movements.mean())
# Out:
# -0.33507916650329544
# 0.26552566800589644
# -0.00010871289069795597

# %%
plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
plt.title('company:Amazon',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Movement',fontsize=15)
plt.plot(norm_movements[1])

plt.subplot(1,2,2)
plt.title('company:Apple',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Movement',fontsize=15)
plt.plot(norm_movements[0])

# %%
#Creating Pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans

#initiate a normalizer
normalizer=Normalizer()

#create KMeans model
kmeans=KMeans(n_clusters=5,max_iter=1000,random_state=1)

#Make a pipeline combining our Normalizer and KMeans model
pipeline=make_pipeline(normalizer,kmeans)

#Fit pipeline to daily stock movements created earlier
pipeline.fit(movements)
predictions=pipeline.predict(movements)
predictions
# Out:
# array([0, 0, 1, 1, 0, 1, 1, 0, 2, 0, 0, 0, 0, 2, 0, 1, 1, 1, 2, 2, 3, 0,
#        4, 4, 4, 2, 0])

# %%
#The companiess and their respective clusters are displayed below
df1=pd.DataFrame({"cluster":predictions,"companies":list(companies_dict)})
df1
# Out:
#     cluster                     companies
# 0         0                        Amazon
# 1         0                         Apple
# 2         1                      Walgreen
# 3         1  Northrop Grumman Corporation
# 4         0                        Boeing
# 5         1               Lockheed Martin
# 6         1                     McDonalds
# 7         0                         Intel
# 8         2                      Navister
# 9         0                           IBM
# 10        0             Texas Instruments
# 11        0                    mastercard
# 12        0                     Microsoft
# 13        2             General Electrics
# 14        0              American Express
# 15        1                         Pepsi
# 16        1                     Coca cola
# 17        1             Jhonson & Jhonson
# 18        2                        Toyota
# 19        2                         Honda
# 20        3        Mitsubishi Corporation
# 21        0        Sony Group Corporation
# 22        4                         Exxon
# 23        4                       Chevron
# 24        4     Valero Energy Corporation
# 25        2                          Ford
# 26        0   Bank of America Corporation

# %%
df1[df1['cluster']==0]
# Out:
#     cluster                    companies
# 0         0                       Amazon
# 1         0                        Apple
# 4         0                       Boeing
# 7         0                        Intel
# 9         0                          IBM
# 10        0            Texas Instruments
# 11        0                   mastercard
# 12        0                    Microsoft
# 14        0             American Express
# 21        0       Sony Group Corporation
# 26        0  Bank of America Corporation

# %%
df1[df1['cluster']==2]
# Out:
#     cluster          companies
# 8         2           Navister
# 13        2  General Electrics
# 18        2             Toyota
# 19        2              Honda
# 25        2               Ford

# %%
#Dimension Reduction-PCA

norm_movements.shape
# Out:
# (27, 1302)

# %%
from sklearn.decomposition import PCA

#Initiate a normalizer
normalizer=Normalizer()

#Reduce the data
pca_data=PCA(n_components=2)

#Create KMEans model
kmeans=KMeans(n_clusters=5,max_iter=1000)

#Make a pipeline combining normalizer,pca and kmeans
pipeline=make_pipeline(normalizer,pca_data,kmeans)

#Fit pipeline to daily stock movements
pipeline.fit(movements)

#Prediction
predictions=pipeline.predict(movements)

#Create DataFrame to store companies and predicted clusters
df2=pd.DataFrame({"clusters":predictions,"companies":list(companies_dict.keys())}).sort_values(by=['clusters'],axis=0)

# %%
df2
# Out:
#     clusters                     companies
# 26         0   Bank of America Corporation
# 4          0                        Boeing
# 21         0        Sony Group Corporation
# 19         0                         Honda
# 9          0                           IBM
# 18         0                        Toyota
# 14         0              American Express
# 3          1  Northrop Grumman Corporation
# 5          1               Lockheed Martin
# 17         1             Jhonson & Jhonson
# 16         1                     Coca cola
# 15         1                         Pepsi
# 24         2     Valero Energy Corporation
# 23         2                       Chevron
# 22         2                         Exxon
# 13         2             General Electrics
# 8          2                      Navister
# 25         2                          Ford
# 12         3                     Microsoft
# 11         3                    mastercard
# 10         3             Texas Instruments
# 7          3                         Intel
# 1          3                         Apple
# 0          3                        Amazon
# 20         4        Mitsubishi Corporation
# 6          4                     McDonalds
# 2          4                      Walgreen

# %%
#Plotting the decision boundary
from sklearn.decomposition import PCA

#Reduce the data
pca_data=PCA(n_components=2).fit_transform(norm_movements)

#Define step size of mesh
h=0.05

#Plot the Decision boundary
x_min,x_max=pca_data[:,0].min()-1,pca_data[:,0].max()+1
y_min,y_max=pca_data[:,1].min()-1,pca_data[:,1].max()+1
xx,yy=np.meshgrid(np.arange(x_min,x_max,h),np.arange(y_min,y_max,h))

# %%
#Obtain labels for each point in the mesh using our trained model
kpredictions=kmeans.predict(np.c_[xx.ravel(),yy.ravel()])

#Put the result into color plot
kpredictions=kpredictions.reshape(xx.shape)

#Define color plot
cmap=plt.cm.Paired

#Plotting Figure
plt.clf()
plt.figure(figsize=(10,10))
plt.imshow(kpredictions,interpolation='nearest',extent=[xx.min(),xx.max(),yy.min(),yy.max()],cmap=cmap,aspect='auto',origin='lower')
plt.plot(pca_data[:,0],pca_data[:,1],'k.',markersize=5)

#Plot the centroid of each cluster as white x
centroids=kmeans.cluster_centers_
plt.scatter(centroids[:,0],centroids[:,1],marker='X',s=169,linewidth=3,color="W",zorder=10)
plt.xlim(x_min,x_max)
plt.ylim(y_min,y_max)
plt.title("KMeans clustering on stock market movements with reduced data")
plt.show()
